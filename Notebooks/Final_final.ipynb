# %%
import numpy as np
import cupy as cp
import matplotlib.pyplot as plt
import seaborn as sns
import rasterio

# %%
x=np.load(r'C:\Users\Darkrai\Projects\iitk proj\ERA5_DATABASE\site_87603_771167\metadata_pressure.npz')

# %%
for i in x:
    print(i)
# Out:
# place_name
# target_lat
# target_lon
# nearest_lat
# nearest_lon
# lat_idx
# lon_idx
# lat0
# lat1
# lon0
# lon1
# tile_latitudes
# tile_longitudes
# pressure_levels

# %%
x['tile_latitudes']
# Out:
# array([9.  , 8.75, 8.5 , 8.25, 8.  , 7.75, 7.5 , 7.25, 7.  , 6.75, 6.5 ,
#        6.25], dtype=float32)
